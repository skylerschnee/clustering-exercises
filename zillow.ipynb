# %% [markdown]
# # Zillow
# - For the following, iterate through the steps you would take to create functions: Write the code to do the following in a jupyter notebook, test it, convert to functions, then create the file to house those functions.
#
# - You will have a zillow.ipynb file and a helper file for each section in the pipeline.
#
# ## Acquire and Summarize

# %% [markdown]
# 1. Acquire data from the cloud database.
# - You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid. - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.
#
# 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)
#
#
# 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import env

# %%
sql_query = '''
    select * 
    from properties_2017
    left join airconditioningtype using(airconditioningtypeid)
    left join architecturalstyletype using(architecturalstyletypeid)
    left join buildingclasstype using(buildingclasstypeid)
    left join heatingorsystemtype using (heatingorsystemtypeid)
    left join propertylandusetype using(propertylandusetypeid)
    left join storytype using(storytypeid)
    left join typeconstructiontype using(typeconstructiontypeid)
    left join unique_properties using(parcelid);
    '''

# %%
def get_zillow_data():
    '''
    This function uses a SQL query 
    and get_connection function from the envy.py file
    to create df of zillow data
    '''    
    df = pd.read_sql(sql_query, env.get_connection('zillow'))
    
    return df

# %%
#assign variable to our function
df = get_zillow_data()

#take a look
df.head()
# Out:
#    parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0  10754147                     NaN          NaN                  269.0
# 1  10759547                     NaN          NaN                  261.0
# 2  10843547                     NaN          NaN                   47.0
# 3  10859147                     NaN          NaN                   47.0
# 4  10879947                     NaN          NaN                   31.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  5.0                       NaN
# 3                    NaN                  3.0                       NaN
# 4                    NaN                  4.0                       NaN
#
#    airconditioningtypeid  id  basementsqft  ...  taxdelinquencyflag  \
# ...

# %%
df.to_csv('zillow_joined.csv')

# %%
#descriptive stats for our numeric columns
df.describe().T
# Out:
#                                   count          mean           std  \
# parcelid                      2985217.0  1.332586e+07  7.909966e+06
# typeconstructiontypeid           6746.0  5.999555e+00  3.840787e-01
# storytypeid                      1623.0  7.000000e+00  0.000000e+00
# propertylandusetypeid         2982285.0  2.600508e+02  1.593121e+01
# heatingorsystemtypeid         1869164.0  4.083750e+00  3.286780e+00
# buildingclasstypeid             12731.0  3.734742e+00  5.003709e-01
# architecturalstyletypeid         6061.0  7.202607e+00  2.436290e+00
# airconditioningtypeid          815362.0  1.945723e+00  3.160507e+00
# id                            2985217.0  1.492608e+06  8.617581e+05
# basementsqft                     1627.0  6.472207e+02  5.387871e+02
# bathroomcnt                   2982260.0  2.216196e+00  1.078250e+00
# bedroomcnt                    2982272.0  3.093362e+00  1.271569e+00
# buildingqualitytypeid         1941395.0  6.280822e+00  1.729923e+00
# ...

# %%
#how many rows and columns do we have
print(f'rows: {df.shape[0]}')
print(f'co1umns: {df.shape[1]}')
# Out:
# rows: 2985217
# co1umns: 66

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2985217 entries, 0 to 2985216
# Data columns (total 66 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      int64
#  1   typeconstructiontypeid        float64
#  2   storytypeid                   float64
#  3   propertylandusetypeid         float64
#  4   heatingorsystemtypeid         float64
#  5   buildingclasstypeid           float64
#  6   architecturalstyletypeid      float64
#  7   airconditioningtypeid         float64
#  8   id                            int64
#  9   basementsqft                  float64
#  10  bathroomcnt                   float64
#  11  bedroomcnt                    float64
#  12  buildingqualitytypeid         float64
#  13  calculatedbathnbr             float64
#  14  decktypeid                    float64
#  15  finishedfloor1squarefeet      float64
#  16  calculatedfinishedsquarefeet  float64
# ...

# %%
def missing_values(df):
    num_rows = len(df)
    missing = df.isnull().sum()
    percent_missing = (missing / num_rows) * 100
    result = pd.concat([missing, percent_missing], axis=1)
    result.columns = ['num_rows_missing', 'pct_rows_missing']
    result.index.name = 'feature'
    return result.sort_values(by='pct_rows_missing', ascending=False)

# %%
mis_val = missing_values(df)

# %%
mis_val
# Out:
#                        num_rows_missing  pct_rows_missing
# feature
# storytypeid                     2983594         99.945632
# storydesc                       2983594         99.945632
# basementsqft                    2983590         99.945498
# yardbuildingsqft26              2982571         99.911363
# fireplaceflag                   2980054         99.827048
# ...                                 ...               ...
# fips                               2932          0.098217
# propertylandusedesc                2932          0.098217
# propertylandusetypeid              2932          0.098217
# id                                    0          0.000000
# parcelid                              0          0.000000
#
# [66 rows x 2 columns]

# %% [markdown]
# # Prepare
#
# 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.
#
# 2. Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
#
#  - The input:
#     - A dataframe
#     - A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#     - A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#     - The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#     - Look up the dropna documentation.
#     - You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
# 3. Encapsulate your work inside of functions in a wrangle_zillow.py module.

# %%
single_fam_df  = df[df['propertylandusetypeid'] == (261 or 279)]

# %%
single_fam_df.shape
# Out:
# (2152863, 67)

# %%
single_fam_df.isnull().sum()
# Out:
# Unnamed: 0                      0
# parcelid                        0
# typeconstructiontypeid    2150205
# storytypeid               2151328
# propertylandusetypeid           0
#                            ...
# buildingclassdesc         2152862
# heatingorsystemdesc        728010
# propertylandusedesc             0
# storydesc                 2151328
# typeconstructiondesc      2150205
# Length: 67, dtype: int64

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    '''
    The input:
    - A dataframe
    - A number between 0 and 1 that represents the proportion, for each column, 
    of rows with non-missing values required to keep the column. 
    - A number between 0 and 1 that represents the proportion, for each row, 
    of columns/variables with non-missing values required to keep the row. 
    
    The output:
    - The dataframe with the columns and rows dropped as indicated.
    '''
    # drop columns that do not meet prop_required_column
    df = df.dropna(thresh=int(prop_required_column*len(df)), axis=1)

    # drop rows that do not meet prop_required_row
    df = df.dropna(thresh=int(prop_required_row*len(df.columns)), axis=0)

    return df
